# %% [markdown]
# # Сборный проект №1
# # "Прогноз для Стримчик"

# %% [markdown]
# ## Задача:
#
# Перед нами данные до 2016 года. Планируется кампанию на 2017-й. Нужно отработать принцип работы с данными.

# %% [markdown]
# ## Информация о данных:
#
# ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# ## Описание данных:
#
# Name — название игры
#
# Platform — платформа
#
# Year_of_Release — год выпуска
#
# Genre — жанр игры
#
# NA_sales — продажи в Северной Америке (миллионы проданных копий)
#
# EU_sales — продажи в Европе (миллионы проданных копий)
#
# JP_sales — продажи в Японии (миллионы проданных копий)
#
# Other_sales — продажи в других странах (миллионы проданных копий)
#
# Critic_Score — оценка критиков (максимум 100)
#
# User_Score — оценка пользователей (максимум 10)
#
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# ## План работы:
#
# -Загрузка данных
#
# -Подготовка данных:
#
#     -Замена названия столбцов (приведите к нижнему регистру);
#
#     -Преобразование данных в нужные типы.
#
#     -Обработайтка пропусков.
#
#     -Подсчет суммарных продаж во всех регионах и запишим их в отдельный столбец.
#
#
# -Исследовательский анализ данных:
#
#      -Посмотрим, сколько игр выпускалось в разные годы.
#
#      -Посмотрим, как менялись продажи по платформам.
#
#      -Возьмем данные за соответствующий актуальный период.
#
#      -Найдем платформы, которые лидируют по продажам, растут или падают.
#
#      -Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам.
#
#      -Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
#
#      -Соотнесем выводы с продажами игр на других платформах.
#
#      -Посмотрим на общее распределение игр по жанрам.
#
# -Составим портрет пользователя каждого региона
#
# -Проверим гипотезы:
#
#      -Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
#      -Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# -Общий вывод

# %% [markdown]
# ## Вывод

# %% [markdown]
# **Изучая начальные данные, можно выделить:**
#
# В столбце "год" - тип значнения флоат, нужен int.
#
# Название столбцов не в змеином регистре.
#
# По количеству данных, можно увидеть пропуски в столбцах: Платформа, Жанр, Оценка критиков, Оценка пользователей, Рейтинг от организации ESRB.
#
# В столбце "оценка пользователей" - тип данных объект, должен быть флоат.
#
# **Подготовили данные:**
#
# -Изменили названия солбцов на змеиный регистр
#
# -Заменили в столбце "оценка пользователей" значение tbd на NuN.
#
# -Заменили тип данных в оценке пользователей с объекта на флоат, так как в столбце храняться только десятичные числа.
#
# -В столбце "название игры" два пропуска, найти через медиану или среднее не представляется возможным, поэтому для дальнейшего исследования, удалили данные строки.
# Пропуски могли появиться из-за того, что могли забыть заполнить название игры, либо не было определено точного названия игры.
#
# -В столбце "дата выхода" имеются 269 пропусков. Данные пропуски могли возникнуть из-за забычивости, либо в названия игр встреается год, например "LMA Manager 2007"
# Год выхода найти по медиане не имеет возможности, поэтому избавились от пропусков, удалением данных строк.
# Также изменили тип значений в толбце на инт.
#
# -В столбце "оценка критиков" много пропусков, но найти их медианным или средним значеним не является возможным, так как проставляя одинаковые значения, можно допустить большую неточность в дальнейшем анализе.
# Данные пропуски могли возникнуть из-за невнимательности в заполнении или из-за того, что при выходе игры критики не успели оценить рейтинг.
# Так как пропусков большое количество, а нам данный столбец будет нужен для дальнейшего исследования, присвоили пропускам значение -1
#
# -В столбце "оценка пользователей" много пропусков, но найти их медианным или средним значеним не является возможным, так как проставляя одинаковые значения, можно допустить большую неточность в дальнейшем анализе.
# Данные пропуски могли возникнуть из-за невнимательности в заполнении или из-за того, что при выходе игры пользователи не успели оценить рейтинг.
# Так как пропусков большое количество, а нам данный столбец будет нужен для дальнейшего исследования, присвоили пропускам значение -1
#
# -Значения в столбце "рейтинг": 'K-A' и 'E' имеют одно и то же значение - Для всех пользователей, поэтому объеденили такие данные с рейтингом 'E'.
#
# -Пропуски в столбце "рейтинг" могут быть из-за невнимательного заполнения, либо рейтинг игры был не определен при выходе, либо не успели присвоить рейтинг данной игре при выходе.
# Поэтому пропуски заполнили: "нет"
#
# -Проверили датафрейм на дубликаты и избавились от них.
#
# -Создали столбец с суммарными продажами во всех регионах.
#
# **Провели исследовательский анализ данных:**
#
# -Посмотрели, сколько игр выпускалось в разные годы:
# что по сравнению с 2001 - 2016 годах, количество выпускаемых играх в более ранние года значительнее меньше, следовательно для исследования они не имеют особого значения.
#
# -Посмотрели, как менялись продажи по платформам:
# Платформа PS2 выпускала игры с 2000 до 2011 года. С 2005 года выручка стала убывать.
# Платформа Х360 с 2005 по 2006. Выручка с 2012 года падает.
# Платформа PS3 с 2006 по 2016. Выручка с 2012 года падает.
# Платформа Wii выпускала игры с 2006 по 2015. С 2010 года вырчка стала падать.
# Платформа DS выпускала игрыс 2004 по 2013 года. С 2009 года выручка стала падать.
# Нашли у платформы аномалию, что выпускала игру в 1985 году, хотя платформа DS была выпущена в 2004 году в Канаде, США и Японии.
#
# Поэтому удалили строку с аномалией.
#
# Платформа PS выпускала игры с 1994 по 2003, с 1999 года выручка стала падать.
#
# -Решили взять данные за соответствующий актуальный период: **2014 - 2016**
# Так как это актуальные более актуальные данные работающих и прибыльных платформ.
# Эти данные помогут построить прогноз на 2017 год.
#
# -Сделали срез данных по актуальным годам.
#
# -Посмотрели какие платформы лидируют по продажам, растут или падают
# и сделали вывод:
#
# По выручке с годами все платформы имеют падение в продажах. Но можно выделить основные, у которых показатели достаточно положительные. Это платформы: PS4, Xone и 3DC. У остальных платформ выручка стремиться к 0.
#
# -Построили график «ящик с усами» по глобальным продажам игр в разбивке по платформам.
#
# По графику "с усами" можно сделать вывод, что каждая платформа имеет выбросы. Но данные выбросы могут характерезоваться выпуском популярной игры из-за чего был "выброс" в продажах, так как видны только положительные.
# Поэтому данные выбросы следует оставить.
#
# -Посмотрели, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
# Выбрали платформу PS4, так как у нее самые большие продажи.
#
# И сделали вывод:
# Исходя из графика рассеивания и коэффициента Пирсона = -0.04 можно сделать вывод, что **оценка пользователей не влияет на продажи игр.**
#
# Исходя из графика рассеивания и коэффициента Пирсона = 0.4 можно сделать вывод, что **оценка критиков влияет, но не сильно на продажи игр.**
#
# -Соотнесли выводы с продажами игр на других платформах.
# Исходя из анализа по популярной плафторме и коэффициентам платформ, где продажи были ниже, что продажи игр не сильно зависят от оценки критиков и пользователей(возможно для некоторых игр именно оценки пользователей дают более менее продажи, как видно из платормы 3DS).
# Но основная зависимость все равно лежит на оценке критиков, хоть и слабая.
#
# -Посмотрели на общее распределение игр по жанрам.
# Жанр action имеет больше всего количество игр, на втором месте Role-Playing.
# Третье место по количетсву занимают жанры adventure и sports.
#
# -Посмотрели распределение прибыли от жанра:
# В жанре action идет самая большая прибыль. Но в жанре shooter, хоть и не самое большое количество игр, но прибыль на втором месте, следовательно, игры в данном жанре набирают популярность. На третьем месте по прибыли являются игры в жанре sports. Жанры выделяются между собой по продажам. Самую маленькую прибыль дают жанры: puzzle и strategy.
# -Построили диаграмму размаха для распределения прибыли от жанра:
#
# Можно сделать вывод, что жанр Shooter является более стабильным и имеет более длинный ряд успешно продающихся игр, так как его медианное значение равно 0.5 млн и он имеет достаточно широкий размах равный 1.6 млн.
#
#
# **Создали портрет пользователя каждого региона.**
#
# Определили для пользователя каждого региона (NA, EU, JP):
#
# -Самые популярные платформы (топ-5).
#
#
# Для региона Северная Америка:
#
# Самая популярная и продающая платформа это PS4 и состовляет 34.71%.
# На втором месте XOne 28.61%,
# X360 является третьим местом и состалвяет 9.96%.
# 3DS и PS3 состовляют примерно одинаковое процентное соотношения 7.97% и 7.76% соответсвенно.
#
# Для Европы:
#
# самая популярная платформа PS4 и равна 48.04%
# На втором месте XOne и равен 17.09%.
# На третьем PS3 и равен 9.44%
#
# Для Японии:
#
# сновная платформа для Японии это 3DS равная 47.52% в процентном соотношении с другими платформами.
# На втором месте платформа PS4 равная 16.13%.
# На третьем месте платформа PSV =15.62%.
# На четвертом PS3 = 12.05%.
# На пятом WiiU = 7.85%
#
# -Построили круговые диаграммы на одном поле и сделали вывод:
#
# **Вывод:**
#
# В Японии идет видимый перевес в популярности платформы 3DS, когда как в других регионах основная платформа это PS4.
#
#
# -Самые популярные жанры (топ-5):
#
# Для региона Северная Америка:
# Самый популярный жанр является shooter и состовляет 27.82%, action является вторым по процентному соотношению и равен 25.53%. На третьем месте sports с процентным соотншением 16.24%
# На четвертом role-playing = 11.78%
# На пятом misc = 5.3%
#
# Для Европы:
# Жанр action стоит на первом месте и равен 27.59%.
# На втором месте жанр shooter = 24.21%.
# На третьем sports = 16.89%.
# На четвертом role-playing = 10.41%
# На пятом racing = 5.22%
#
# Уже на данном этапе видна разница между регионами, жанр racing в Северной Америке не входит топ 5, когда как в Еропу входит.
#
# Для Японии:
# На первом месте стоит role-playing = 33.47%.
# На втором месте action =31.78%
# Жанры fighting, misc и shooter равны 6.84%, 6.03%, 5.23% соответсвенно.
#
# -Построили круговые диаграммы на одном поле и сделали вывод:
#
# **Вывод:**
#
# В Японии превалирует жанр role-playing, хотя в других регионах по процентному соотношению он стоит на третьих местах.
# Когда как в Европе самый популярный жанр Action, а в Северной Америке Shooter.
#
#
# -Влияние рейтинга ESRB на продажи в отдельном регионе
#
#
# Для региона Северная Америка:
#
# 'Доля продаж в Северной Америке'
#
# рейтинг   доля
#
# M       42.56%
#
# нет     32.52%
#
# E       38.11%
#
# T       39.29%
#
# E10+    46.35%
#
# Для Европы:
#
# 'Доля продаж в Европе'
#
# рейтинг   доля
#
# M       41.24%
#
# нет     29.62%
#
# E       43.61%
#
# T       34.36%
#
# E10+    36.49%
#
# Для Японии:
#
# 'Доля продаж в Японии'
#
# рейтинг    доля
#
# E        6.71%
#
# E10+     6.22%
#
# M        3.53%
#
# T       14.9%
#
# нет     28.59%
#
#
# **Вывод:**
#
# По графикам можно сделать вывод, что в Японии основная доля рейтинга от всех - "не определен", но на втором месте идут пользователи входящие в категорию подростки.
# В Европе же основной категорией являются пользователи рейтинг "Для всех пользователей".
# Для Северной Америки - E10+(Старше 10-ти лет)
#
# **Проверили гипотезы:**
#
# **Гипотеза №1:**
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# Вывод:
# С вероятностью в 10% такое или большее различие можно получить случайно. Рейтинги платформы Xbox, могут быть равны средним пользовательским рейтингам платформы PC.
#
# -Приняли что общепринятые пороговые значения — 5 % и 1 %. Выберем 1%, как достаточно малый.
#
# **Гипотеза №2:** Средние пользовательские рейтинги жанров Action и Sports разные.
#
# Вывод:
# Средние cредние пользовательские рейтинги жанров Action, не равны средним пользовательским рейтингам жанров Sports.

# %% [markdown]
# ## 1. Импортирование библиотек:

# %%
import pandas as pd
import os
import seaborn
import matplotlib.pyplot as plt
from scipy import stats as st
import numpy as np
from scipy.stats import binom
from math import sqrt

# %% [markdown]
# ## 2. Загрузка данных:

# %% [markdown]
# Изучая данные, можно выделить:
#
# В столбце "год" - тип значнения флоат, нужен int.
#
# Название столбцов не в змеином регистре.
#
# По количеству данных, можно увидеть пропуски в столбцах: Платформа, Жанр, Оценка критиков, Оценка пользователей, Рейтинг от организации ESRB.
#
# В столбце "оценка пользователей" - тип данных объект, должен быть флоат
#
# Для понимания рейтинга организаций:
#
# «EC» («Early childhood») — «Для детей младшего возраста.
#
# «E» («Everyone») — «Для всех»
#
# «E10+» («Everyone 10 and older») — «Для всех старше 10 лет.
#
# «T» («Teen») — «Подросткам»
#
# «M» («Mature») — «От 17 лет»
#
# «AO» («Adults Only 18+») — «Только для взрослых»
#
# «RP» («Rating Pending»») — «Рейтинг ожидается»
#
# «K-A» (for Kids to Adults) - «Для детей и взрослых»

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ## 3. Подготовка данных:

# %%
#Изменим регистр столбцов:
data.columns = data.columns.str.lower()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %%
#Изменим в столбце "оценка пользователей" тип данных объект на флоат:
#Для начала посмотрим уникальные значения столбца:
print(data['user_score'].unique())

#Значение 'tbd' не позволит изменить значение столбца на флоат, поэтому посмотрим его количество:
print(data['user_score'].value_counts())

#Заменим значение 'tbd' на пропуск:

data.loc[data['user_score'] == 'tbd', 'user_score'] = np.NaN

print(data['user_score'].unique())

#Заменим тип данных на флоат:
data['user_score'] = data['user_score'].astype(float)

data.info()
# Out:
# ['8' nan '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
#  '7.2' '9.2' '7' '7.3' '4.3' '7.6' '5.7' '5' '9.1' '6.5' 'tbd' '8.8' '6.9'
#  '9.4' '6.8' '6.1' '6.7' '5.4' '4' '4.9' '4.5' '9.3' '6.2' '4.2' '6' '3.7'
#  '4.1' '5.8' '5.6' '5.5' '4.4' '4.6' '5.9' '3.9' '3.1' '2.9' '5.2' '3.3'
#  '4.7' '5.1' '3.5' '2.5' '1.9' '3' '2.7' '2.2' '2' '9.5' '2.1' '3.6' '2.8'
#  '1.8' '3.8' '0' '1.6' '9.6' '2.4' '1.7' '1.1' '0.3' '1.5' '0.7' '1.2'
#  '2.3' '0.5' '1.3' '0.2' '0.6' '1.4' '0.9' '1' '9.7']
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
#        ...
# 2.3       2
# 0.5       2
# 1.9       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64
# ['8' nan '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
# ...

# %% [markdown]
# Замениди в столбце "оценка пользователей" значение tbd на NuN.
# Заменили тип данных в оценке пользователей с объекта на флоат, так как в столбце храняться только десятичные числа.

# %%
#Посмотрим уникальные значения и количество пропусков в столбцах.
print(data.isna().sum())

print(data['name'].unique())

data = data.dropna(subset=['name']) 

print(data.shape)
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64
# ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ...
#  'Woody Woodpecker in Crazy Castle 5' 'LMA Manager 2007'
#  'Haitaka no Psychedelica']
# (16713, 11)

# %% [markdown]
# В столбце "название игры" два пропуска, найти через медиану или среднее не представляется возможным, поэтому для дальнейшего исследования, удалим данные строки.
# Пропуски могли появиться из-за того, что могли забыть заполнить название игры, либо не было определено точного названия игры.

# %%
print(data['year_of_release'].isna().sum())
print(data['year_of_release'].unique())
data['year_of_release'] = data['year_of_release'].fillna(value = 0)

# print(data.query('year_of_release == 0')
#       .groupby('year_of_release')['na_sales', 'eu_sales', 'jp_sales', 'other_sales'].sum())

data = data.dropna(subset=['year_of_release']) 

#Заменим значения с флоат, на инт:
data['year_of_release'] = data['year_of_release'].astype(int)

data.info()
# Out:
# 269
# [2006. 1985. 2008. 2009. 1996. 1989. 1984. 2005. 1999. 2007. 2010. 2013.
#  2004. 1990. 1988. 2002. 2001. 2011. 1998. 2015. 2012. 2014. 1992. 1997.
#  1993. 1994. 1982. 2016. 2003. 1986. 2000.   nan 1995. 1991. 1981. 1987.
#  1980. 1983.]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# ...

# %% [markdown]
# В столбце "дата выхода" имеются 269 пропусков. Данные пропуски могли возникнуть из-за забычивости, либо в названия игр встреается год, например "LMA Manager 2007"
# Год выхода найти по медиане не имеет возможности, поэтому избавимся от пропусков, удалением данных строк.
# Также изменим тип значений в толбце на инт.

# %%
print(data['critic_score'].unique())
data['critic_score'] = data['critic_score'].fillna(value = -1)
print(data['critic_score'].isna().sum())
print(data['critic_score'].unique())
# Out:
# [76. nan 82. 80. 89. 58. 87. 91. 61. 97. 95. 77. 88. 83. 94. 93. 85. 86.
#  98. 96. 90. 84. 73. 74. 78. 92. 71. 72. 68. 62. 49. 67. 81. 66. 56. 79.
#  70. 59. 64. 75. 60. 63. 69. 50. 25. 42. 44. 55. 48. 57. 29. 47. 65. 54.
#  20. 53. 37. 38. 33. 52. 30. 32. 43. 45. 51. 40. 46. 39. 34. 35. 41. 36.
#  28. 31. 27. 26. 19. 23. 24. 21. 17. 22. 13.]
# 0
# [76. -1. 82. 80. 89. 58. 87. 91. 61. 97. 95. 77. 88. 83. 94. 93. 85. 86.
#  98. 96. 90. 84. 73. 74. 78. 92. 71. 72. 68. 62. 49. 67. 81. 66. 56. 79.
#  70. 59. 64. 75. 60. 63. 69. 50. 25. 42. 44. 55. 48. 57. 29. 47. 65. 54.
#  20. 53. 37. 38. 33. 52. 30. 32. 43. 45. 51. 40. 46. 39. 34. 35. 41. 36.
#  28. 31. 27. 26. 19. 23. 24. 21. 17. 22. 13.]

# %% [markdown]
# В столбце "оценка критиков" много пропусков, но найти их медианным или средним значеним не является возможным, так как проставляя одинаковые значения, можно допустить большую неточность в дальнейшем анализе.
# Данные пропуски могли возникнуть из-за невнимательности в заполнении или из-за того, что при выходе игры критики не успели оценить рейтинг.
# Так как пропусков большое количество, а нам данный столбец будет нужен для дальнейшего исследования, присвоим пропускам значение -1

# %%
print(data['user_score'].unique()) 
data['user_score'] = data['user_score'].fillna(value = -1)
print(data['user_score'].isna().sum())
print(data['user_score'].unique())
# Out:
# [8.  nan 8.3 8.5 6.6 8.4 8.6 7.7 6.3 7.4 8.2 9.  7.9 8.1 8.7 7.1 3.4 5.3
#  4.8 3.2 8.9 6.4 7.8 7.5 2.6 7.2 9.2 7.  7.3 4.3 7.6 5.7 5.  9.1 6.5 8.8
#  6.9 9.4 6.8 6.1 6.7 5.4 4.  4.9 4.5 9.3 6.2 4.2 6.  3.7 4.1 5.8 5.6 5.5
#  4.4 4.6 5.9 3.9 3.1 2.9 5.2 3.3 4.7 5.1 3.5 2.5 1.9 3.  2.7 2.2 2.  9.5
#  2.1 3.6 2.8 1.8 3.8 0.  1.6 9.6 2.4 1.7 1.1 0.3 1.5 0.7 1.2 2.3 0.5 1.3
#  0.2 0.6 1.4 0.9 1.  9.7]
# 0
# [ 8.  -1.   8.3  8.5  6.6  8.4  8.6  7.7  6.3  7.4  8.2  9.   7.9  8.1
#   8.7  7.1  3.4  5.3  4.8  3.2  8.9  6.4  7.8  7.5  2.6  7.2  9.2  7.
#   7.3  4.3  7.6  5.7  5.   9.1  6.5  8.8  6.9  9.4  6.8  6.1  6.7  5.4
#   4.   4.9  4.5  9.3  6.2  4.2  6.   3.7  4.1  5.8  5.6  5.5  4.4  4.6
#   5.9  3.9  3.1  2.9  5.2  3.3  4.7  5.1  3.5  2.5  1.9  3.   2.7  2.2
#   2.   9.5  2.1  3.6  2.8  1.8  3.8  0.   1.6  9.6  2.4  1.7  1.1  0.3
#   1.5  0.7  1.2  2.3  0.5  1.3  0.2  0.6  1.4  0.9  1.   9.7]

# %% [markdown]
# В столбце "оценка пользователей" много пропусков, но найти их медианным или средним значеним не является возможным, так как проставляя одинаковые значения, можно допустить большую неточность в дальнейшем анализе.
# Данные пропуски могли возникнуть из-за невнимательности в заполнении или из-за того, что при выходе игры пользователи не успели оценить рейтинг.
#
# Так как пропусков большое количество, а нам данный столбец будет нужен для дальнейшего исследования, присвоим пропускам значение -1

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />плюс технические проблемы и отсутствие ресурсов на сбор информации (время, деньги)

# %%
print(data['rating'].isna().sum())
print(data['rating'].unique())
# Out:
# 6764
# ['E' nan 'M' 'T' 'E10+' 'K-A' 'AO' 'EC' 'RP']

# %% [markdown]
# Значения в столбце "рейтинг": 'K-A' и 'E' имеют одно и то же значение - Для всех пользователей, поэтому объеденим такие данные с рейтингом 'E'.

# %%
data.loc[(data['rating'] == 'K-A'), 'rating'] = 'E'
print(data['rating'].unique())
data.info()
# Out:
# ['E' nan 'M' 'T' 'E10+' 'AO' 'EC' 'RP']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     16713 non-null  float64
#  9   user_score       16713 non-null  float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# Пропуски в столбце "рейтинг" могут быть из-за невнимательного заполнения, либо рейтинг игры был не определен при выходе, либо не успели присвоить рейтинг данной игре при выходе.
# Поэтому пропуски заполним: "нет"

# %%
def replace_rating(nans, right):
    data['rating'] = data['rating'].replace(nans, right)
    
replace_rating(np.NaN, 'нет')

print(data['rating'].unique())
# Out:
# ['E' 'нет' 'M' 'T' 'E10+' 'AO' 'EC' 'RP']

# %%
#Проверим пропуски в таблице
print(data.isna().sum())
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %%
#Создадим столбец с суммарными продажами во всех регионах:
data['sum_sales'] =  data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis = 1)

display(data.head(20))
# Out:
#                                             name platform  year_of_release  \
# 0                                     Wii Sports      Wii             2006
# 1                              Super Mario Bros.      NES             1985
# 2                                 Mario Kart Wii      Wii             2008
# 3                              Wii Sports Resort      Wii             2009
# 4                       Pokemon Red/Pokemon Blue       GB             1996
# 5                                         Tetris       GB             1989
# 6                          New Super Mario Bros.       DS             2006
# 7                                       Wii Play      Wii             2006
# 8                      New Super Mario Bros. Wii      Wii             2009
# 9                                      Duck Hunt      NES             1984
# 10                                    Nintendogs       DS             2005
# ...

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     16713 non-null  float64
#  9   user_score       16713 non-null  float64
#  10  rating           16713 non-null  object
#  11  sum_sales        16713 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.7+ MB

# %%
#Проверим на дубликаты:
data['name'] = data['name'].str.lower()
data['platform'] = data['platform'].str.lower()

print(data[data.duplicated(['name', 'platform', 'year_of_release'])])
data.duplicated(subset=['name', 'platform', 'year_of_release']).sum()
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 16230  madden nfl 13      ps3             2012  Sports       0.0      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  sum_sales
# 16230       0.0          0.0          83.0         5.5      E       0.01
# 1

# %% [markdown]
# В таблице есть один дубликат, поэтому избавимся от него.

# %%
data = data.drop_duplicates(subset=['name', 'platform', 'year_of_release'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16712 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16712 non-null  object
#  1   platform         16712 non-null  object
#  2   year_of_release  16712 non-null  int64
#  3   genre            16712 non-null  object
#  4   na_sales         16712 non-null  float64
#  5   eu_sales         16712 non-null  float64
#  6   jp_sales         16712 non-null  float64
#  7   other_sales      16712 non-null  float64
#  8   critic_score     16712 non-null  float64
#  9   user_score       16712 non-null  float64
#  10  rating           16712 non-null  object
#  11  sum_sales        16712 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.7+ MB

# %% [markdown]
# -Изменили названия солбцов на змеиный регистр
#
# -Заменили в столбце "оценка пользователей" значение tbd на NuN.
#
# -Заменили тип данных в оценке пользователей с объекта на флоат, так как в столбце храняться только десятичные числа.
#
# -В столбце "название игры" два пропуска, найти через медиану или среднее не представляется возможным, поэтому для дальнейшего исследования, удалили данные строки.
# Пропуски могли появиться из-за того, что могли забыть заполнить название игры, либо не было определено точного названия игры.
#
# -В столбце "дата выхода" имеются 269 пропусков. Данные пропуски могли возникнуть из-за забычивости, либо в названия игр встреается год, например "LMA Manager 2007"
# Год выхода найти по медиане не имеет возможности, поэтому избавились от пропусков, удалением данных строк.
# Также изменили тип значений в толбце на инт.
#
# -В столбце "оценка критиков" много пропусков, но найти их медианным или средним значеним не является возможным, так как проставляя одинаковые значения, можно допустить большую неточность в дальнейшем анализе.
# Данные пропуски могли возникнуть из-за невнимательности в заполнении или из-за того, что при выходе игры критики не успели оценить рейтинг.
# Так как пропусков большое количество, а нам данный столбец будет нужен для дальнейшего исследования, присвоили пропускам значение -1
#
# -В столбце "оценка пользователей" много пропусков, но найти их медианным или средним значеним не является возможным, так как проставляя одинаковые значения, можно допустить большую неточность в дальнейшем анализе.
# Данные пропуски могли возникнуть из-за невнимательности в заполнении или из-за того, что при выходе игры пользователи не успели оценить рейтинг.
# Так как пропусков большое количество, а нам данный столбец будет нужен для дальнейшего исследования, присвоили пропускам значение -1
#
# -Значения в столбце "рейтинг": 'K-A' и 'E' имеют одно и то же значение - Для всех пользователей, поэтому объеденили такие данные с рейтингом 'E'.
#
# -Пропуски в столбце "рейтинг" могут быть из-за невнимательного заполнения, либо рейтинг игры был не определен при выходе, либо не успели присвоить рейтинг данной игре при выходе.
# Поэтому пропуски заполнили: "нет"
#
# -Проверили датафрейм на дубликаты и избавились от них.
#
# -Создали столбец с суммарными продажами во всех регионах.

# %% [markdown]
# ## 4. Исследовательский анализ данных

# %%
#Посмотрим, сколько игр выпускалось в разные годы:
print(data.groupby('year_of_release')['name'].count().plot.bar(figsize=(12, 6), grid = True))
plt.title("Количество выпускаемых игр по годам");
plt.xlabel("Год");
plt.ylabel("Количество игр");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Для наглядности выведим в столбчатый график.
# По графику видно, что по сравнению с 2001 - 2016 годах, количество выпускаемых играх в более ранние года значительнее меньше, следовательно для исследования они не имеют особого значения.

# %%
#Посмотрим, как менялись продажи по платформам.
#Найдем платформы с наибольшими суммарными продажами:
print(data.groupby('platform')['sum_sales'].sum().sort_values(ascending = False))

#Построим распределение по годам:
print(data.query('platform in ["ps2", "x360", "ps3", "wii", "ds", "ps" ]')
     .pivot_table(index='year_of_release', columns = 'platform', values='sum_sales', aggfunc='sum')
      .plot.bar(grid=True, figsize=(12, 6), rot = 0))
plt.title("Распределение выпускаемых игр по платформам по годам");
plt.xlabel("Год");
plt.ylabel("Сумма выручки");
# Out:
# platform
# ps2     1255.77
# x360     971.42
# ps3      939.64
# wii      907.51
# ds       806.12
# ps       730.86
# gba      317.85
# ps4      314.14
# psp      294.05
# pc       259.52
# 3ds      259.00
# xb       257.74
# gb       255.46
# nes      251.05
# n64      218.68
# snes     200.04
# gc       198.93
# xone     159.32
# 2600      96.98
# wiiu      82.19
# psv       54.07
# sat       33.59
# gen       28.35
# dc        15.95
# scd        1.86
# ng         1.44
# ws         1.42
# tg16       0.16
# 3do        0.10
# gg         0.04
# pcfx       0.03
# Name: sum_sales, dtype: float64
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# По графику видно, что у платформы PS продажи шли до 2002, но у PS2 подолжились с 2000 до 2011, у PS3 c 2006 до 2016, распределение нормальное, то есть имеет вид  возрастающе-убывающей.
# у платформы DS продажи шли до 2013 года.
# У платформы Wii с 2006 до 2016 года.
# У платформы X360 c 2005 до 2016 года.

# %%
#Для ps2
print(data.query('platform == "ps2"')
     .pivot_table(index='year_of_release', columns = 'platform', values='sum_sales', aggfunc='sum')
      .plot.bar(grid=True, figsize=(12, 6), rot = 0))
plt.title("Распределение выпускаемых игр PS2 по годам");
plt.xlabel("Год");
plt.ylabel("Сумма выручки");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Платформа PS2 выпускала игры с 2000 до 2011 года. С 2005 года выручка стала убывать.

# %%
#Для х360:
print(data.query('platform == "x360"')
     .pivot_table(index='year_of_release', columns = 'platform', values='sum_sales', aggfunc='sum')
      .plot.bar(grid=True, figsize=(12, 6), rot = 0))
plt.title("Распределение выпускаемых игр X360 по годам");
plt.xlabel("Год");
plt.ylabel("Сумма выручки");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Платформа Х360 с 2005 по 2006. Выручка с 2012 года падает.

# %%
#Для ps3:
print(data.query('platform == "ps3"')
     .pivot_table(index='year_of_release', columns = 'platform', values='sum_sales', aggfunc='sum')
      .plot.bar(grid=True, figsize=(12, 6), rot = 0))
plt.title("Распределение выпускаемых игр PS3 по годам");
plt.xlabel("Год");
plt.ylabel("Сумма выручки");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Платформа PS3 с 2006 по 2016. Выручка с 2012 года падает.

# %%
#Для wii:
print(data.query('platform == "wii"')
     .pivot_table(index='year_of_release', columns = 'platform', values='sum_sales', aggfunc='sum')
      .plot.bar(grid=True, figsize=(12, 6), rot = 0))
plt.title("Распределение выпускаемых игр Wii по годам");
plt.xlabel("Год");
plt.ylabel("Сумма выручки");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Платформа Wii выпускала игры с 2006 по 2015. С 2010 года вырчка стала падать.

# %%
#Для ds:
print(data.query('platform == "ds"')
     .pivot_table(index='year_of_release', columns = 'platform', values='sum_sales', aggfunc='sum')
      .plot.bar(grid=True, figsize=(12, 6), rot = 0))
plt.title("Распределение выпускаемых игр DS по годам");
plt.xlabel("Год");
plt.ylabel("Сумма выручки");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Платформа DS выпускала игрыс 2004 по 2013 года. С 2009 года выручка стала падать.

# %% [markdown]
# Заметили по графику аномалию в 1985 году, поэтому удалим строку с аномалией, так как платформа DS была выпущена в 2004 году в Канаде, США и Японии.

# %%
print(data.loc[(data['year_of_release']==1985)& (data['platform']== 'ds')])
# Out:
#                                       name platform  year_of_release   genre  \
# 15957  strongest tokyo university shogi ds       ds             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15957       0.0       0.0      0.02          0.0          -1.0        -1.0
#
#       rating  sum_sales
# 15957    нет       0.02

# %%
data = data.drop(data.loc[(data['year_of_release']==1985)& (data['platform']== 'ds')].index)

# %% [markdown]
# Проверим график:

# %%
#Для ds:
print(data.query('platform == "ds"')
     .pivot_table(index='year_of_release', columns = 'platform', values='sum_sales', aggfunc='sum')
      .plot.bar(grid=True, figsize=(12, 6), rot = 0))
plt.title("Распределение выпускаемых игр DS по годам");
plt.xlabel("Год");
plt.ylabel("Сумма выручки");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Для ps:
print(data.query('platform == "ps"')
     .pivot_table(index='year_of_release', columns = 'platform', values='sum_sales', aggfunc='sum')
      .plot.bar(grid=True, figsize=(12, 6), rot = 0))
plt.title("Распределение выпускаемых игр PS по годам");
plt.xlabel("Год");
plt.ylabel("Сумма выручки");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Платформа PS выпускала игры с 1994 по 2003, с 1999 года выручка стала падать.

# %% [markdown]
# Возьмем данные за соответствующий актуальный период: **2014 - 2016**
# Так как это актуальные более актуальные данные работающих и прибыльных платформ.
# Эти данные помогут построить прогноз на 2017 год.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отличное определение актуального периода для исследования, молодец

# %%
#Сделаем срез данных по актуальным годам:
data = data.query('year_of_release in [2014, 2015, 2016]')

display(data)
# Out:
#                                             name platform  year_of_release  \
# 31                     call of duty: black ops 3      ps4             2015
# 42                            grand theft auto v      ps4             2014
# 47     pokemon omega ruby/pokemon alpha sapphire      3ds             2014
# 77                                       fifa 16      ps4             2015
# 87                  star wars battlefront (2015)      ps4             2015
# ...                                          ...      ...              ...
# 16703                           strawberry nauts      psv             2016
# 16707                           aiyoku no eustia      psv             2014
# 16710              samurai warriors: sanada maru      ps3             2016
# 16712                    haitaka no psychedelica      psv             2016
# 16714                        winning post 8 2016      psv             2016
#
# ...

# %%
# Посмотрим какие платформы лидируют по продажам, растут или падают.
print(data.pivot_table(index='year_of_release', columns = 'platform', values='sum_sales', aggfunc='sum')
      .plot(grid=True, figsize=(12, 6)))
plt.title("Распределение выпускаемых игр по годам");
plt.xlabel("Год");
plt.ylabel("Сумма выручки");
plt.xticks(np.arange(2014, 2017));
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# По графику можно сделать вывод:
# По выручке с годами все платформы имеют падение в продажах. Но можно выделить основные, у которых показатели достаточно положительные. Это платформы: PS4, Xone и 3DC. У остальных платформ выручка стремиться к 0.

# %%
#Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам.
data.boxplot(column='sum_sales', by='platform', figsize=(12, 6))
plt.ylim(-0.2, 2)
plt.show()

print(data.groupby('platform')['sum_sales'].describe())
# Out:
#           count      mean       std   min     25%    50%     75%    max
# platform
# 3ds       212.0  0.408868  1.188368  0.01  0.0300  0.090  0.2500  11.68
# pc        151.0  0.179139  0.329359  0.01  0.0200  0.060  0.2000   3.05
# ps3       219.0  0.311324  0.633059  0.01  0.0400  0.110  0.3250   5.27
# ps4       376.0  0.766356  1.614969  0.01  0.0575  0.185  0.6900  14.63
# psp        13.0  0.027692  0.027735  0.01  0.0100  0.020  0.0200   0.09
# psv       295.0  0.075932  0.141591  0.01  0.0200  0.040  0.0900   1.96
# wii        11.0  0.460909  0.625451  0.01  0.0350  0.180  0.7550   2.01
# wiiu       73.0  0.588767  1.161467  0.01  0.0500  0.190  0.5700   7.09
# x360      111.0  0.434414  0.628967  0.01  0.0700  0.180  0.5050   4.28
# xone      228.0  0.615614  1.046513  0.01  0.0500  0.205  0.6325   7.39

# %% [markdown]
# По графику "с усами" можно сделать вывод, что каждая платформа имеет выбросы. Но данные выбросы могут характерезоваться выпуском популярной игры из-за чего был "выброс" в продажах, так как видны только положительные.
# Поэтому данные выбросы следует оставить.

# %%
#Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
#Выберем платформу PS4, так как у нее самые большие продажи.
data_ps4 = data.query('platform == "ps4"')
print(data_ps4['user_score'].unique())
data_ps4_user = data_ps4[data_ps4['user_score'] != -1]
#Для отзывов пользователей:

print(data_ps4_user['sum_sales'].corr(data_ps4_user['user_score']).round(2))     
data_ps4_user.plot(x='sum_sales', y='user_score', kind='scatter', alpha = 0.2, figsize=(12, 6))
plt.title("Распределение продаж по отзывам пользователей");
# Out:
# [-1.   8.3  4.3  5.7  5.   6.5  6.1  7.9  8.1  3.4  8.4  6.3  7.7  9.2
#   4.9  7.6  6.7  7.   8.2  6.8  5.9  8.6  7.3  7.4  6.   7.1  5.1  6.6
#   5.4  4.5  8.8  6.2  7.8  8.5  7.2  7.5  5.5  6.9  3.6  3.7  5.6  8.
#   8.7  5.8  3.8  4.7  3.3  1.5  4.1  6.4  1.9  3.   3.5  2.   2.3]
# -0.04

# %% [markdown]
# Исходя из графика рассеивания и коэффициента Пирсона = -0.04 можно сделать вывод, что оценка пользователей не влияет на продажи
# игр.

# %%
#Для отзывов критиков:

print(data_ps4['critic_score'].unique())
data_ps4_critic = data_ps4[data_ps4['critic_score'] != -1]

print(data_ps4_critic['sum_sales'].corr(data_ps4_critic['critic_score']).round(2))

data_ps4_critic.plot(x='sum_sales', y='critic_score', kind='scatter', alpha = 0.2, figsize=(12, 6))
plt.title("Распределение продаж по отзывам критиков");
# Out:
# [-1. 97. 82. 83. 85. 87. 76. 93. 86. 77. 88. 80. 92. 70. 84. 73. 81. 90.
#  74. 71. 89. 79. 68. 75. 63. 61. 62. 69. 78. 67. 65. 72. 60. 48. 66. 59.
#  57. 32. 53. 47. 58. 45. 19. 44. 64. 42. 25. 52. 43. 31. 55. 49. 51.]
# 0.4

# %% [markdown]
# Исходя из графика рассеивания и коэффициента Пирсона = 0.4 можно сделать вывод, что оценка критиков влияет, но не сильно на продажи игр.

# %%
#Выберем платформу XOne, так как на втором месте по продажам.
data_xone = data.query('platform == "xone"')

print(data_xone['user_score'].unique())
data_xone_user = data_xone[data_xone['user_score'] != -1]

print(data_xone['critic_score'].unique())
data_xone_critic = data_xone[data_xone['critic_score'] != -1]

#Для отзывов пользователей:
print(data_xone_user['sum_sales'].corr(data_xone_user['user_score']).round(2))
data_xone_user.plot(x='sum_sales', y='user_score', kind='scatter', alpha = 0.2, figsize=(12, 6))
plt.title("Распределение продаж по отзывам пользователей");
#Для отзывов критиков:
print(data_xone_critic['sum_sales'].corr(data_xone_critic['critic_score']).round(2))
data_xone_critic.plot(x='sum_sales', y='critic_score', kind='scatter', alpha = 0.2, figsize=(12, 6))
plt.title("Распределение продаж по отзывам критиков");
# Out:
# [-1.   7.9  5.4  6.4  6.2  4.1  5.5  7.5  4.4  7.2  3.1  6.1  8.2  6.9
#   6.3  5.8  6.6  7.3  8.   9.2  7.8  8.4  5.9  5.1  5.2  7.7  7.4  5.6
#   7.   6.7  4.6  5.7  6.8  8.1  6.   7.1  3.2  8.6  8.5  4.3  5.3  4.
#   8.3  8.7  2.1  7.6  4.9  8.9  1.6  4.2  8.8]
# [-1. 97. 81. 84. 88. 72. 75. 82. 85. 86. 78. 87. 80. 74. 91. 77. 83. 71.
#  89. 90. 95. 76. 79. 70. 64. 67. 60. 56. 69. 59. 63. 66. 68. 53. 73. 58.
#  51. 49. 65. 39. 62. 54. 20. 35. 48. 55. 45. 52.]
# -0.07
# 0.43

# %% [markdown]
# По графику рассеивания видно, что для платформы XOne так же видна очень слабая связь от отзывов критиков.

# %%
#Выберем платформу 3DS, так как на 3-м месте по продажам.
data_3ds = data.query('platform == "3ds"')

print(data_3ds['user_score'].unique())
data_3ds_user = data_3ds[data_3ds['user_score'] != -1]

print(data_3ds['critic_score'].unique())
data_3ds_critic = data_3ds[data_3ds['critic_score'] != -1]

#Для отзывов пользователей:
print(data_3ds_user['sum_sales'].corr(data_3ds_user['user_score']).round(2))
data_3ds_user.plot(x='sum_sales', y='user_score', kind='scatter', alpha = 0.3, figsize=(12, 6))
plt.title("Распределение продаж по отзывам пользователей");

#Для отзывов критиков:
print(data_3ds_critic['sum_sales'].corr(data_3ds_critic['critic_score']).round(2))
data_3ds_critic.plot(x='sum_sales', y='critic_score', kind='scatter', alpha = 0.3, figsize=(12, 6))
plt.title("Распределение продаж по отзывам критиков");
# Out:
# [-1.   8.7  6.9  9.   8.8  6.1  7.6  8.1  5.4  7.2  7.   7.7  7.4  8.2
#   2.4  6.4  4.8  6.6  8.5  6.8  6.3  3.4  7.1  7.9  7.8  5.6  7.5  5.1
#   5.8  8.4]
# [-1. 86. 66. 89. 80. 64. 69. 73. 81. 83. 76. 78. 57. 61. 68. 47. 67. 79.
#  77. 58. 60. 72. 90. 71. 65. 63. 51. 70. 82. 46. 45. 43. 26.]
# 0.22
# 0.31

# %% [markdown]
# По графикам рассеивания для платформы 3DS можно сделать вывод, что связь между продажами и оценки критиков есть, но не сильная.

# %%
#Соотнесем выводы с продажами игр на других платформах.

print(data.groupby('platform')['sum_sales'].sum().sort_values(ascending = False))
# Out:
# platform
# ps4     288.15
# xone    140.36
# 3ds      86.68
# ps3      68.18
# x360     48.22
# wiiu     42.98
# pc       27.05
# psv      22.40
# wii       5.07
# psp       0.36
# Name: sum_sales, dtype: float64

# %% [markdown]
# Исходя из анализа по популярной плафторме и коэффициентам платформ, где продажи были ниже, что продажи игр не сильно зависят от оценки критиков и пользователей(возможно для некоторых игр именно оценки пользователей дают более менее продажи, как видно из платормы 3DS).
# Но основная зависимость все равно лежит на оценке критиков, хоть и слабая.

# %%
#Посмотрим на общее распределение игр по жанрам.
print(data.groupby('genre')['name'].count()
      .plot.bar(figsize=(12, 6), rot=0))
plt.title("Распределение выпускаемых игр по жанрам");
plt.xlabel("Жанры");
plt.ylabel("Количество игр");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# По графику, видно, что жанр action имеет больше всего количество игр, на втором месте Role-Playing.
# Третье место по количетсву занимают жанры adventure и sports.

# %%
#Посмотрим распределение прибыли от жанра:
print(data.groupby('genre')['sum_sales'].sum()
      .plot.bar(figsize=(12, 6), rot=0))
plt.title("Распределение прибыли от жанра");
plt.xlabel("Жанры");
plt.ylabel("Прибыль");
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Можно увидеть, что в жанре action идет самая большая прибыль.
# Но в жанре shooter, хоть и не самое большое количество игр, но прибыль на втором месте, следовательно, игры в данном жанре набирают популярность.
# На третьем месте по прибыли являются игры в жанре sports.
# Жанры выделяются между собой по продажам. Самую маленькую прибыль дают жанры: puzzle и strategy.

# %%
#Посмотрим распределение прибыли от жанра с выбросами:
data.boxplot(column='sum_sales', by='genre', figsize=(12, 6))
plt.ylim(-0.2, 5)
plt.show()

print(data.groupby('genre')['sum_sales'].describe())
# Out:
#               count      mean       std   min     25%    50%     75%    max
# genre
# Action        619.0  0.322068  0.798181  0.01  0.0300  0.090  0.2800  12.62
# Adventure     185.0  0.094865  0.203147  0.01  0.0200  0.030  0.0800   1.66
# Fighting       60.0  0.470333  1.188053  0.01  0.0600  0.125  0.3200   7.55
# Misc          113.0  0.332301  0.736999  0.01  0.0300  0.090  0.3200   5.27
# Platform       38.0  0.476053  0.722561  0.01  0.0625  0.140  0.4675   3.21
# Puzzle         14.0  0.157857  0.320629  0.01  0.0200  0.045  0.1000   1.19
# Racing         69.0  0.398841  0.963716  0.01  0.0300  0.090  0.2500   7.09
# Role-Playing  221.0  0.459005  1.177284  0.01  0.0500  0.110  0.3600  11.68
# Shooter       128.0  1.335469  2.050567  0.01  0.1725  0.515  1.6175  14.63
# Simulation     44.0  0.298409  0.646925  0.01  0.0200  0.100  0.3275   3.05
# Sports        161.0  0.680000  1.239736  0.01  0.0600  0.180  0.6400   8.58
# ...

# %%
#Посмотрим распределение прибыли от жанра без выбросов:
data.boxplot(column='sum_sales', by='genre', figsize=(12, 6))
plt.ylim(0, 1.65)
plt.show()

# %% [markdown]
# Рассматривая диграмму размаха можно сделать вывод, что жанр Shooter является более стабильным и имеет более длинный ряд успешно продающихся игр, так как его медианное значение равно 0.5 млн и он имеет достаточно широкий размах равный 1.6 млн.

# %%
#Посмотрим распределение прибыли от жанра с выбросами:
data.boxplot(column='sum_sales', by='genre', figsize=(12, 4))
# plt.ylim(-0.2, 5)
plt.show()

# %% [markdown]
# ## 5. Портрет пользователя каждого региона.

# %%
#Определим для пользователя каждого региона (NA, EU, JP):

#Самые популярные платформы (топ-5).
#Для региона Северная Америка:
platform_na = data.groupby('platform')['na_sales'].sum().sort_values(ascending = False).reset_index()
print(platform_na.head())

platform_na['platform'] = platform_na['platform'].where((platform_na['platform']== 'ps4')| 
                                                            (platform_na['platform']== 'xone')|
                                                            (platform_na['platform']== 'ps3')|
                                                            (platform_na['platform']== 'x360')|
                                                            (platform_na['platform']== '3ds'), 'other')
print(platform_na)
print(platform_na.groupby('platform')['na_sales'].sum().sort_values(ascending = False)
      .plot(kind='pie', y='share', autopct='%.2f'))
# Out:
#   platform  na_sales
# 0      ps4     98.61
# 1     xone     81.27
# 2     x360     28.30
# 3      3ds     22.64
# 4      ps3     22.05
#   platform  na_sales
# 0      ps4     98.61
# 1     xone     81.27
# 2     x360     28.30
# 3      3ds     22.64
# 4      ps3     22.05
# 5    other     19.36
# 6    other      7.23
# 7    other      2.52
# 8    other      2.08
# 9    other      0.00
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %% [markdown]
# Исходя из графика, можно увидеть соотношение:
# Что самая популярная и продающая платформа это PS4 и состовляет 34.71%.
# На втором месте XOne 28.61%,
# X360 является третьим местом и состалвяет 9.96%.
# 3DS и PS3 состовляют примерно одинаковое процентное соотношения 7.97% и 7.76% соответсвенно.

# %%
#Самые популярные жанры (топ-5):
genre_na = data.groupby('genre')['na_sales'].sum().sort_values(ascending = False).reset_index()
display(genre_na.head())

genre_na['genre'] = genre_na['genre'].where((genre_na['genre']== 'Role-Playing')| 
                                                            (genre_na['genre']== 'Action')|
                                                            (genre_na['genre']== 'Shooter')|
                                                            (genre_na['genre']== 'Misc')|
                                                            (genre_na['genre']== 'Sports'), 'other')

display(genre_na)
print(genre_na.groupby('genre')['na_sales'].sum().sort_values(ascending = False)
     .plot(kind='pie', y='share', autopct='%.2f'))
# Out:
#           genre  na_sales
# 0       Shooter     79.02
# 1        Action     72.53
# 2        Sports     46.13
# 3  Role-Playing     33.47
# 4          Misc     15.05
#            genre  na_sales
# 0        Shooter     79.02
# 1         Action     72.53
# 2         Sports     46.13
# 3   Role-Playing     33.47
# 4           Misc     15.05
# 5          other     12.43
# 6          other      8.74
# 7          other      6.79
# 8          other      5.64
# 9          other      2.63
# 10         other      0.98
# 11         other      0.65
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %% [markdown]
# Самый популярный жанр является shooter и состовляет 27.82%, action является вторым по процентному соотношению и равен 25.53%. На третьем месте sports с процентным соотншением 16.24%
#
# На четвертом role-playing = 11.78%
#
# На пятом misc = 5.3%

# %%
#Посмотрим, влияет ли рейтинг ESRB на продажи во всех регионах:
sum_rating= data.groupby('rating')['sum_sales'].sum().sort_values(ascending = False)
print(sum_rating.plot.bar(figsize=(12, 6), rot = 0))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Во всех регионах самый популярный рейтинг М - это пользователи старше 17 лет, на втором месте неопределенный рейтинг, на третьем Е - для всех пользователей.

# %%
#Посмотрим, влияет ли рейтинг ESRB на продажи в отдельном регионе
na_rating = data.groupby('rating')['na_sales'].sum().sort_values(ascending = False)
print(na_rating.plot.bar(figsize=(12, 6), rot = 0))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Исходя из графика самый прибыльный рейтинг в Северной Америка является M - это пользователи старше 17,  видимо из-за того, что shooter является самым популярным.
# На втором месте по прибыли является рейтинг, который неопределен.
# На третьем месте E - это игры для всех пользователей.

# %%
#Найдем долю рейтинга в Северной Америке:
share_na = na_rating / sum_rating * 100
display('Доля продаж в Северной Америке', share_na )
# Out:
# 'Доля продаж в Северной Америке'
# rating
# M       42.562020
# нет     32.527517
# E       38.113123
# T       39.291839
# E10+    46.358817
# dtype: float64

# %%
#Самые популярные платформы (топ-5).
#Для Европы:

platform_eu = data.groupby('platform')['eu_sales'].sum().sort_values(ascending = False).reset_index()
print(platform_eu.head())

platform_eu['platform'] = platform_eu['platform'].where((platform_eu['platform']== 'ps4')| 
                                                            (platform_eu['platform']== 'xone')|
                                                            (platform_eu['platform']== 'ps3')|
                                                            (platform_eu['platform']== 'pc')|
                                                            (platform_eu['platform']== '3ds'), 'other')
print(platform_eu)
print(platform_eu.groupby('platform')['eu_sales'].sum().sort_values(ascending = False)
      .plot(kind='pie', y='share', autopct='%.2f'))
# Out:
#   platform  eu_sales
# 0      ps4    130.04
# 1     xone     46.25
# 2      ps3     25.54
# 3       pc     17.97
# 4      3ds     16.12
#   platform  eu_sales
# 0      ps4    130.04
# 1     xone     46.25
# 2      ps3     25.54
# 3       pc     17.97
# 4      3ds     16.12
# 5    other     15.49
# 6    other     13.15
# 7    other      3.53
# 8    other      2.59
# 9    other      0.00
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %% [markdown]
# По процентому соотношению можно сделать вывод, что самая популярная платформа PS4 и равна 48.04%
# На втором месте XOne и равен 17.09%.
# На третьем PS3 и равен 9.44%

# %%
#Самые популярные жанры (топ-5):
genre_eu = data.groupby('genre')['eu_sales'].sum().sort_values(ascending = False).reset_index()
display(genre_eu.head())

genre_eu['genre'] = genre_eu['genre'].where((genre_eu['genre']== 'Role-Playing')| 
                                                            (genre_eu['genre']== 'Action')|
                                                            (genre_eu['genre']== 'Shooter')|
                                                            (genre_eu['genre']== 'Sports')|
                                                            (genre_eu['genre']== 'Racing'), 'other')

display(genre_eu)
print(genre_eu.groupby('genre')['eu_sales'].sum().sort_values(ascending = False)
     .plot(kind='pie', y='share', autopct='%.2f'))
# Out:
#           genre  eu_sales
# 0        Action     74.68
# 1       Shooter     65.52
# 2        Sports     45.73
# 3  Role-Playing     28.17
# 4        Racing     14.13
#            genre  eu_sales
# 0         Action     74.68
# 1        Shooter     65.52
# 2         Sports     45.73
# 3   Role-Playing     28.17
# 4         Racing     14.13
# 5          other     12.86
# 6          other      7.30
# 7          other      6.80
# 8          other      6.69
# 9          other      6.49
# 10         other      1.79
# 11         other      0.52
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %% [markdown]
# На круговой диаграмме видно, что жанр action стоит на первом месте и равен 27.59%.
#
# На втором месте жанр shooter = 24.21%.
#
# На третьем sports = 16.89%.
#
# На четвертом role-playing = 10.41%
#
# На пятом racing = 5.22%
#
# Уже на данном этапе видна разница между регионами, жанр racing в Северной Америке не входит топ 5, когда как в Еропу входит.

# %%
#Посмотрим, влияет ли рейтинг ESRB на продажи в отдельном регионе
eu_rating = data.groupby('rating')['eu_sales'].sum().sort_values(ascending = False)
print(eu_rating.plot.bar(figsize=(12, 6), rot = 0))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# По столбчатой диаграмме можно выделить, что рейтинг М - пользователи старше 17 лет превалирует над другими,
# на втором месте неопределенный рейтинг и Е - для всех пользователей
# На третьем месте Т - пользователи подростков.
# На четвертом месте рейтинг E10+ - пользователи старше 10-ти лет.

# %%
#Найдем долю рейтинга в Европе:
share_eu = eu_rating / sum_rating * 100
display('Доля продаж в Европе', share_eu )
# Out:
# 'Доля продаж в Европе'
# rating
# M       41.246579
# нет     29.627582
# E       43.611508
# T       34.369010
# E10+    36.495536
# dtype: float64

# %%
#Самые популярные платформы (топ-5).
#Для Японии:
platform_jp = data.groupby('platform')['jp_sales'].sum().sort_values(ascending = False).reset_index()
print(platform_jp.head())

platform_jp['platform'] = platform_jp['platform'].where((platform_jp['platform']== 'ps4')| 
                                                            (platform_jp['platform']== 'wiiu')|
                                                            (platform_jp['platform']== 'ps3')|
                                                            (platform_jp['platform']== 'psv')|
                                                            (platform_jp['platform']== '3ds'), 'other')
print(platform_jp)
print(platform_jp.groupby('platform')['jp_sales'].sum().sort_values(ascending = False)
      .plot(kind='pie', y='share', autopct='%.2f'))
# Out:
#   platform  jp_sales
# 0      3ds     44.24
# 1      ps4     15.02
# 2      psv     14.54
# 3      ps3     11.22
# 4     wiiu      7.31
#   platform  jp_sales
# 0      3ds     44.24
# 1      ps4     15.02
# 2      psv     14.54
# 3      ps3     11.22
# 4     wiiu      7.31
# 5    other      0.36
# 6    other      0.32
# 7    other      0.08
# 8    other      0.00
# 9    other      0.00
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %% [markdown]
# По круговой диаграмме можно сделать вывод, что основная платформа для Японии это 3DS равная 47.52% в процентном соотношении с другими платформами.
# На втором месте платформа PS4 равная 16.13%.
# На третьем месте платформа PSV =15.62%.
# На четвертом PS3 = 12.05%.
# На пятом WiiU = 7.85%

# %%
#Самые популярные жанры (топ-5):
genre_jp = data.groupby('genre')['jp_sales'].sum().sort_values(ascending = False).reset_index()
display(genre_jp.head())

genre_jp['genre'] = genre_jp['genre'].where((genre_jp['genre']== 'Role-Playing')| 
                                                            (genre_jp['genre']== 'Action')|
                                                            (genre_jp['genre']== 'Shooter')|
                                                            (genre_jp['genre']== 'Misc')|
                                                            (genre_jp['genre']== 'Fighting'), 'other')

display(genre_jp)
print(genre_jp.groupby('genre')['jp_sales'].sum().sort_values(ascending = False)
     .plot(kind='pie', y='share', autopct='%.2f'))
# Out:
#           genre  jp_sales
# 0  Role-Playing     31.16
# 1        Action     29.58
# 2      Fighting      6.37
# 3          Misc      5.61
# 4       Shooter      4.87
#            genre  jp_sales
# 0   Role-Playing     31.16
# 1         Action     29.58
# 2       Fighting      6.37
# 3           Misc      5.61
# 4        Shooter      4.87
# 5          other      3.60
# 6          other      3.26
# 7          other      2.69
# 8          other      2.31
# 9          other      1.76
# 10         other      0.95
# 11         other      0.93
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %% [markdown]
# По круговой диаграмме соотношений жанров, можно сделать выовод, что на первом месте стоит role-playing = 33.47%.
# На втором месте action =31.78%
# Жанры fighting, misc и shooter равны 6.84%, 6.03%, 5.23% соответсвенно.

# %%
#Посмотрим, влияет ли рейтинг ESRB на продажи в отдельном регионе
jp_rating = data.groupby('rating')['jp_sales'].sum().sort_values(ascending = False)
print(jp_rating.plot.bar(figsize=(12, 6), rot = 0))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# По столбчатой диаграмме можно сделать вывод, что в Японии основные пользователи входят в рейтинг, который неопределен.
# На втором месте рейтинг Т - для пользователей подростков.
# На третьем месте Е - для всех пользователей
# На четвертом месте М - пользователи старше 17 лет.
# И на последнем месте Е10+ - пользователи старше 10 лет.
#
# Исходя из популярных жанров и отличия от дургих регионов, можно выделить различия популярность среди пользователей, входящих в определенную возрастную группу.

# %%
#Найдем долю рейтинга в Японии:
share_jp = jp_rating / sum_rating * 100
display('Доля продаж в Японии', share_jp )
# Out:
# 'Доля продаж в Японии'
# rating
# E        6.715241
# E10+     6.222098
# M        3.535799
# T       14.909715
# нет     28.597276
# dtype: float64

# %%
#Выведим круговые диаграммы для жанров для наглядности на одно поле:
plt.figure(figsize=(21, 9))
plt.suptitle('Обзор рынка по жанрам', fontsize = 25)

plt.subplot(1, 3, 1)
ax1 = genre_jp.groupby('genre')['jp_sales'].sum().sort_values(ascending = False)\
.plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность жанров в Японии', fontsize = 18 )

plt.subplot(1, 3, 2)
ax2 = genre_eu.groupby('genre')['eu_sales'].sum().sort_values(ascending = False)\
.plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность жанров в Европе', fontsize = 18 )

plt.subplot(1, 3, 3)
ax3 = genre_na.groupby('genre')['na_sales'].sum().sort_values(ascending = False)\
.plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность жанров в Северной Америке', fontsize = 18 )

ax1.set_ylabel('')
ax2.set_ylabel('')
ax3.set_ylabel('')
plt.show()

# %% [markdown]
# Можно сделать вывод, что в Японии превалирует жанр role-playing, хотя в других регионах по процентному соотношению он стоит на третьих местах.
# Когда как в Европе самый популярный жанр Action, а в Северной Америке Shooter.

# %%
#Выведим круговые диаграммы для платформ для наглядности на одно поле:
plt.figure(figsize=(21, 9))
plt.suptitle('Обзор рынка по платформам', fontsize = 25)

plt.subplot(1, 3, 1)
ax1 = platform_jp.groupby('platform')['jp_sales'].sum().sort_values(ascending = False)\
.plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность платформ в Японии', fontsize = 18 )

plt.subplot(1, 3, 2)
ax2 = platform_eu.groupby('platform')['eu_sales'].sum().sort_values(ascending = False)\
.plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность платформ в Европе', fontsize = 18 )

plt.subplot(1, 3, 3)
ax3 = platform_na.groupby('platform')['na_sales'].sum().sort_values(ascending = False)\
.plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность платформ в Северной Америке', fontsize = 18 )

ax1.set_ylabel('')
ax2.set_ylabel('')
ax3.set_ylabel('')
plt.show()

# %% [markdown]
# Можно сделать вывод, что в Японии идет видимый перевес в популярности платформы 3DS, когда как в других регионах основная платформа это PS4.

# %%
#Выведим круговые диаграммы для рейтинга для наглядности на одно поле:
plt.figure(figsize=(21, 9))
plt.suptitle('Обзор рынка по рейтингу', fontsize = 25)

plt.subplot(1, 3, 1)
ax1 = share_jp.\
plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность рейтингов в Японии', fontsize = 18 )

plt.subplot(1, 3, 2)
ax2 = share_eu.\
plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность рейтингов в Европе', fontsize = 18 )

plt.subplot(1, 3, 3)
ax3 = share_na.\
plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность рейтингов в Северной Америке', fontsize = 18 )

ax1.set_ylabel('')
ax2.set_ylabel('')
ax3.set_ylabel('')
plt.show()

# %% [markdown]
# По графикам можно сделать вывод, что в Японии основная доля рейтинга от всех - "не определен", но на втором месте идут пользователи входящие в категорию подростки.
# В Европе же основной категорией являются пользователи рейтинг "Для всех пользователей".
# Для Северной Америки - E10+(Старше 10-ти лет)

# %%
#Выведим круговые диаграммы для жанров для наглядности на одно поле:
plt.figure(figsize=(21, 9))
plt.suptitle('Обзор рынка по жанрам', fontsize = 25)

plt.subplot(1, 3, 1)
ax1 = genre_jp.groupby('genre')['jp_sales'].sum().sort_values(ascending = False)\
.plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность жанров в Японии', fontsize = 18 )

plt.subplot(1, 3, 2)
ax2 = genre_eu.groupby('genre')['eu_sales'].sum().sort_values(ascending = False)\
.plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность жанров в Европе', fontsize = 18 )

plt.subplot(1, 3, 3)
ax3 = genre_na.groupby('genre')['na_sales'].sum().sort_values(ascending = False)\
.plot(kind='pie', y='share', autopct='%.2f', title = 'Популярность жанров в Северной Америке', fontsize = 18 )

ax1.set_ylabel('')
ax2.set_ylabel('')
ax3.set_ylabel('')
plt.show()

# %% [markdown]
# ## 6. Проверка гипотез.

# %% [markdown]
# **Гипотеза №1:**
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# Нулевая гипотеза: Средние пользовательские рейтинги платформы Xbox, равны средним пользовательским рейтингам платформы PC.
# Альтернативная гипотеза:Средние пользовательские рейтинги платформы Xbox, не равны средним пользовательским рейтингам платформы PC.
# Если p-value меньше порогового значения alpha, то гипотезу отвергаем. Иначе - не отвергаем.

# %%
data_xbox = data.query('platform=="xone"')

data_xbox = data_xbox[data_xbox['user_score'] != -1]

display(data_xbox.head())

data_pc = data.query('platform=="pc"')

data_pc = data_pc[data_pc['user_score'] != -1]

display(data_pc.head())

alpha = 0.05 # уровень статистической значимости
# если p-value окажется меньше него, отвергнем гипотезу

results = st.ttest_ind(data_xbox['user_score'], data_pc['user_score'])

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
#                                name platform  year_of_release         genre  \
# 165              grand theft auto v     xone             2014        Action
# 179  call of duty: advanced warfare     xone             2014       Shooter
# 242               halo 5: guardians     xone             2015       Shooter
# 270                       fallout 4     xone             2015  Role-Playing
# 373         assassin's creed: unity     xone             2014        Action
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 165      2.81      2.19      0.00         0.47          97.0         7.9
# 179      3.22      1.55      0.01         0.48          81.0         5.4
# 242      2.78      1.27      0.03         0.41          84.0         6.4
# 270      2.51      1.32      0.01         0.38          88.0         6.2
# 373      2.27      0.90      0.00         0.33          72.0         4.1
#
#     rating  sum_sales
# 165      M       5.47
# 179      M       5.26
# ...

# %% [markdown]
# Полученное значение p-value больше заданного уровня значимости, поэтому нельзя отвергнуть нулевую гипотезу. Есть основания говорить, что с вероятностью в 10% такое или большее различие можно получить случайно.Рейтинги платформы Xbox, могут быть равны средним пользовательским рейтингам платформы PC.
# Приняли что общепринятые пороговые значения — 5 % и 1 %. Выберем 1%, как достаточно малый.

# %% [markdown]
# **Гипотеза №2:** Средние пользовательские рейтинги жанров Action и Sports разные.
#
# Нулевая гипотеза: Средние пользовательские рейтинги жанров Action, равны средним пользовательским рейтингам жанров Sports. Альтернативная гипотеза:Средние пользовательские рейтинги жанров Action, не равны средним пользовательским рейтингам жанров Sports.
# Если p-value меньше порогового значения alpha, то гипотезу отвергаем. Иначе - не отвергаем.

# %%
data_action = data.query('genre=="Action"')

data_action = data_action[data_action['user_score'] != -1]

display(data_action.head())

data_sports = data.query('genre=="Sports"')

data_sports = data_sports[data_sports['user_score'] != -1]

display(data_sports.head())

alpha = 0.01 # уровень статистической значимости
# если p-value окажется меньше него, отвергнем гипотезу

results = st.ttest_ind(data_action['user_score'], data_sports['user_score'])

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
#                                        name platform  year_of_release   genre  \
# 42                       grand theft auto v      ps4             2014  Action
# 165                      grand theft auto v     xone             2014  Action
# 231  uncharted: the nathan drake collection      ps4             2015  Action
# 295                              watch dogs      ps4             2014  Action
# 304                 assassin's creed: unity      ps4             2014  Action
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 42       3.96      6.31      0.38         1.97          97.0         8.3
# 165      2.81      2.19      0.00         0.47          97.0         7.9
# 231      2.07      1.71      0.08         0.76          86.0         8.1
# 295      1.40      1.90      0.11         0.64          80.0         6.3
# 304      1.19      2.07      0.08         0.62          70.0         4.9
#
#     rating  sum_sales
# 42       M      12.62
# ...

# %% [markdown]
# Полученное значение p-value больше заданного уровня значимости, поэтому можно отвергнуть нулевую гипотезу. Есть основания говорить, что cредние пользовательские рейтинги жанров Action, не равны средним пользовательским рейтингам жанров Sports.

# %% [markdown]
# ## Вывод.

# %% [markdown]
# **Изучая начальные данные, можно выделить:**
#
# В столбце "год" - тип значнения флоат, нужен int.
#
# Название столбцов не в змеином регистре.
#
# По количеству данных, можно увидеть пропуски в столбцах: Платформа, Жанр, Оценка критиков, Оценка пользователей, Рейтинг от организации ESRB.
#
# В столбце "оценка пользователей" - тип данных объект, должен быть флоат.
#
# **Подготовили данные:**
#
# -Изменили названия солбцов на змеиный регистр
#
# -Заменили в столбце "оценка пользователей" значение tbd на NuN.
#
# -Заменили тип данных в оценке пользователей с объекта на флоат, так как в столбце храняться только десятичные числа.
#
# -В столбце "название игры" два пропуска, найти через медиану или среднее не представляется возможным, поэтому для дальнейшего исследования, удалили данные строки.
# Пропуски могли появиться из-за того, что могли забыть заполнить название игры, либо не было определено точного названия игры.
#
# -В столбце "дата выхода" имеются 269 пропусков. Данные пропуски могли возникнуть из-за забычивости, либо в названия игр встреается год, например "LMA Manager 2007"
# Год выхода найти по медиане не имеет возможности, поэтому избавились от пропусков, удалением данных строк.
# Также изменили тип значений в толбце на инт.
#
# -В столбце "оценка критиков" много пропусков, но найти их медианным или средним значеним не является возможным, так как проставляя одинаковые значения, можно допустить большую неточность в дальнейшем анализе.
# Данные пропуски могли возникнуть из-за невнимательности в заполнении или из-за того, что при выходе игры критики не успели оценить рейтинг.
# Так как пропусков большое количество, а нам данный столбец будет нужен для дальнейшего исследования, присвоили пропускам значение -1
#
# -В столбце "оценка пользователей" много пропусков, но найти их медианным или средним значеним не является возможным, так как проставляя одинаковые значения, можно допустить большую неточность в дальнейшем анализе.
# Данные пропуски могли возникнуть из-за невнимательности в заполнении или из-за того, что при выходе игры пользователи не успели оценить рейтинг.
# Так как пропусков большое количество, а нам данный столбец будет нужен для дальнейшего исследования, присвоили пропускам значение -1
#
# -Значения в столбце "рейтинг": 'K-A' и 'E' имеют одно и то же значение - Для всех пользователей, поэтому объеденили такие данные с рейтингом 'E'.
#
# -Пропуски в столбце "рейтинг" могут быть из-за невнимательного заполнения, либо рейтинг игры был не определен при выходе, либо не успели присвоить рейтинг данной игре при выходе.
# Поэтому пропуски заполнили: "нет"
#
# -Проверили датафрейм на дубликаты и избавились от них.
#
# -Создали столбец с суммарными продажами во всех регионах.
#
# **Провели исследовательский анализ данных:**
#
# -Посмотрели, сколько игр выпускалось в разные годы:
# что по сравнению с 2001 - 2016 годах, количество выпускаемых играх в более ранние года значительнее меньше, следовательно для исследования они не имеют особого значения.
#
# -Посмотрели, как менялись продажи по платформам:
# Платформа PS2 выпускала игры с 2000 до 2011 года. С 2005 года выручка стала убывать.
# Платформа Х360 с 2005 по 2006. Выручка с 2012 года падает.
# Платформа PS3 с 2006 по 2016. Выручка с 2012 года падает.
# Платформа Wii выпускала игры с 2006 по 2015. С 2010 года вырчка стала падать.
# Платформа DS выпускала игрыс 2004 по 2013 года. С 2009 года выручка стала падать.
# Нашли у платформы аномалию, что выпускала игру в 1985 году, хотя платформа DS была выпущена в 2004 году в Канаде, США и Японии.
#
# Поэтому удалили строку с аномалией.
#
# Платформа PS выпускала игры с 1994 по 2003, с 1999 года выручка стала падать.
#
# -Решили взять данные за соответствующий актуальный период: **2014 - 2016**
# Так как это актуальные более актуальные данные работающих и прибыльных платформ.
# Эти данные помогут построить прогноз на 2017 год.
#
# -Сделали срез данных по актуальным годам.
#
# -Посмотрели какие платформы лидируют по продажам, растут или падают
# и сделали вывод:
#
# По выручке с годами все платформы имеют падение в продажах. Но можно выделить основные, у которых показатели достаточно положительные. Это платформы: PS4, Xone и 3DC. У остальных платформ выручка стремиться к 0.
#
# -Построили график «ящик с усами» по глобальным продажам игр в разбивке по платформам.
#
# По графику "с усами" можно сделать вывод, что каждая платформа имеет выбросы. Но данные выбросы могут характерезоваться выпуском популярной игры из-за чего был "выброс" в продажах, так как видны только положительные.
# Поэтому данные выбросы следует оставить.
#
# -Посмотрели, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
# Выбрали платформу PS4, так как у нее самые большие продажи.
#
# И сделали вывод:
# Исходя из графика рассеивания и коэффициента Пирсона = -0.04 можно сделать вывод, что **оценка пользователей не влияет на продажи игр.**
#
# Исходя из графика рассеивания и коэффициента Пирсона = 0.4 можно сделать вывод, что **оценка критиков влияет, но не сильно на продажи игр.**
#
# -Соотнесли выводы с продажами игр на других платформах.
# Исходя из анализа по популярной плафторме и коэффициентам платформ, где продажи были ниже, что продажи игр не сильно зависят от оценки критиков и пользователей(возможно для некоторых игр именно оценки пользователей дают более менее продажи, как видно из платормы 3DS).
# Но основная зависимость все равно лежит на оценке критиков, хоть и слабая.
#
# -Посмотрели на общее распределение игр по жанрам.
# Жанр action имеет больше всего количество игр, на втором месте Role-Playing.
# Третье место по количетсву занимают жанры adventure и sports.
#
# -Посмотрели распределение прибыли от жанра:
# В жанре action идет самая большая прибыль. Но в жанре shooter, хоть и не самое большое количество игр, но прибыль на втором месте, следовательно, игры в данном жанре набирают популярность. На третьем месте по прибыли являются игры в жанре sports. Жанры выделяются между собой по продажам. Самую маленькую прибыль дают жанры: puzzle и strategy.
# -Построили диаграмму размаха для распределения прибыли от жанра:
#
# Можно сделать вывод, что жанр Shooter является более стабильным и имеет более длинный ряд успешно продающихся игр, так как его медианное значение равно 0.5 млн и он имеет достаточно широкий размах равный 1.6 млн.
#
#
# **Создали портрет пользователя каждого региона.**
#
# Определили для пользователя каждого региона (NA, EU, JP):
#
# -Самые популярные платформы (топ-5).
#
#
# Для региона Северная Америка:
#
# Самая популярная и продающая платформа это PS4 и состовляет 34.71%.
# На втором месте XOne 28.61%,
# X360 является третьим местом и состалвяет 9.96%.
# 3DS и PS3 состовляют примерно одинаковое процентное соотношения 7.97% и 7.76% соответсвенно.
#
# Для Европы:
#
# самая популярная платформа PS4 и равна 48.04%
# На втором месте XOne и равен 17.09%.
# На третьем PS3 и равен 9.44%
#
# Для Японии:
#
# сновная платформа для Японии это 3DS равная 47.52% в процентном соотношении с другими платформами.
# На втором месте платформа PS4 равная 16.13%.
# На третьем месте платформа PSV =15.62%.
# На четвертом PS3 = 12.05%.
# На пятом WiiU = 7.85%
#
# -Построили круговые диаграммы на одном поле и сделали вывод:
#
# **Вывод:**
#
# В Японии идет видимый перевес в популярности платформы 3DS, когда как в других регионах основная платформа это PS4.
#
#
# -Самые популярные жанры (топ-5):
#
# Для региона Северная Америка:
# Самый популярный жанр является shooter и состовляет 27.82%, action является вторым по процентному соотношению и равен 25.53%. На третьем месте sports с процентным соотншением 16.24%
# На четвертом role-playing = 11.78%
# На пятом misc = 5.3%
#
# Для Европы:
# Жанр action стоит на первом месте и равен 27.59%.
# На втором месте жанр shooter = 24.21%.
# На третьем sports = 16.89%.
# На четвертом role-playing = 10.41%
# На пятом racing = 5.22%
#
# Уже на данном этапе видна разница между регионами, жанр racing в Северной Америке не входит топ 5, когда как в Еропу входит.
#
# Для Японии:
# На первом месте стоит role-playing = 33.47%.
# На втором месте action =31.78%
# Жанры fighting, misc и shooter равны 6.84%, 6.03%, 5.23% соответсвенно.
#
# -Построили круговые диаграммы на одном поле и сделали вывод:
#
# **Вывод:**
#
# В Японии превалирует жанр role-playing, хотя в других регионах по процентному соотношению он стоит на третьих местах.
# Когда как в Европе самый популярный жанр Action, а в Северной Америке Shooter.
#
#
# -Влияние рейтинга ESRB на продажи в отдельном регионе
#
#
# Для региона Северная Америка:
#
# 'Доля продаж в Северной Америке'
#
# рейтинг   доля
#
# M       42.56%
#
# нет     32.52%
#
# E       38.11%
#
# T       39.29%
#
# E10+    46.35%
#
# Для Европы:
#
# 'Доля продаж в Европе'
#
# рейтинг   доля
#
# M       41.24%
#
# нет     29.62%
#
# E       43.61%
#
# T       34.36%
#
# E10+    36.49%
#
# Для Японии:
#
# 'Доля продаж в Японии'
#
# рейтинг    доля
#
# E        6.71%
#
# E10+     6.22%
#
# M        3.53%
#
# T       14.9%
#
# нет     28.59%
#
#
# **Вывод:**
#
# По графикам можно сделать вывод, что в Японии основная доля рейтинга от всех - "не определен", но на втором месте идут пользователи входящие в категорию подростки.
# В Европе же основной категорией являются пользователи рейтинг "Для всех пользователей".
# Для Северной Америки - E10+(Старше 10-ти лет)
#
# **Проверили гипотезы:**
#
# **Гипотеза №1:**
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# Вывод:
# С вероятностью в 10% такое или большее различие можно получить случайно. Рейтинги платформы Xbox, могут быть равны средним пользовательским рейтингам платформы PC.
#
# -Приняли что общепринятые пороговые значения — 5 % и 1 %. Выберем 1%, как достаточно малый.
#
# **Гипотеза №2:** Средние пользовательские рейтинги жанров Action и Sports разные.
#
# Вывод:
# Средние cредние пользовательские рейтинги жанров Action, не равны средним пользовательским рейтингам жанров Sports.
